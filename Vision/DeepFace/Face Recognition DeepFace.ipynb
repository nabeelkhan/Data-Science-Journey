# %%
# !pip install deepface

# %%
from deepface import DeepFace

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
def verify(img1_path , img2_path,model_name):
    img1 = cv2.imread(img1_path)
    img2 = cv2.imread(img2_path)
    plt.imshow(img1[:, :, ::-1])
    plt.show()
    plt.imshow(img2[:, :, ::-1])
    plt.show()
    result = DeepFace.verify(img1_path,img2_path,model_name = model_name)
    print("Result : ",result)
    
    verification = result["verified"]
    if verification:
        print("\n\nThey are same")
    else:
        print("\n\nThey are different")

# %%
verify("img1.jpg","img2.jpg","VGG-Face")
# Out:
# Result :  {'verified': False, 'distance': 0.6853585970475792, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
#
#
# They are different

# %%
verify("img2.jpg","img3.jpg","VGG-Face")
# Out:
# Result :  {'verified': False, 'distance': 0.5640299574120133, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
#
#
# They are different

# %%
verify("img1.jpg","img4.jpg","VGG-Face")
# Out:
# Result :  {'verified': True, 'distance': 0.1705068239335651, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
#
#
# They are same

# %%
verify("img2.jpg","img5.jpg","VGG-Face")
# Out:
# Result :  {'verified': True, 'distance': 0.35751249084044445, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
#
#
# They are same

# %%
verify("img3.jpg","img6.jpg","VGG-Face")
# Out:
# Result :  {'verified': True, 'distance': 0.28907967564531456, 'max_threshold_to_verify': 0.4, 'model': 'VGG-Face', 'similarity_metric': 'cosine'}
#
#
# They are same
